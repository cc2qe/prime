# %%
x <- seq(0,100*pi,0.1)

# %%
mypal <- c('steelblue', 'indianred')

# %%
max <- 20

# plot(x/(pi/2), sin(x), xlim=c(0,max), type='l', col=mypal[1])
# points(x/(pi/1), sin(x), xlim=c(0,max), type='l', col=mypal[1])
plot(1, xlim=c(0,max), ylim=c(-1,1), type='n', xlab='', ylab='')

for (i in 2:max) {
    points(x/(pi/i), sin(x), xlim=c(0,max), type='l', col=mypal[1])
}

abline(h=0)
# Out:
# plot without title

# %%
max <- 20

# plot(x/(pi/2), sin(x), xlim=c(0,max), type='l', col=mypal[1])
# points(x/(pi/1), sin(x), xlim=c(0,max), type='l', col=mypal[1])
plot(1, xlim=c(0,max), ylim=c(-1,1), type='n', xlab='', ylab='')

for (i in 2:max) {
    points(x/(pi/i), sin(x), xlim=c(0,max), type='l', col=mypal[1])
}

for (i in max:2) {
    points(max - x/(pi/i), sin(x), xlim=c(0,max), type='l', col=mypal[2])
}

abline(h=0)

# goldbach pairs
g <- c(3,7,13,17)
points(g, rep(0, length(g)))
# Out:
# plot without title

# %%
rep(0, length(g))
# Out:
# Error in eval(expr, envir, enclos): object 'g' not found
# Traceback:

# %%
max <- 100

# plot(x/(pi/2), sin(x), xlim=c(0,max), type='l', col=mypal[1])
# points(x/(pi/1), sin(x), xlim=c(0,max), type='l', col=mypal[1])
plot(1, xlim=c(0,max), ylim=c(-1,1), type='n', xlab='', ylab='')

for (i in 2:max) {
    points(x/(pi/i), sin(x), xlim=c(0,max), type='l', col=mypal[1])
}

for (i in max:2) {
    points(max - x/(pi/i), sin(x), xlim=c(0,max), type='l', col=mypal[2])
}


abline(h=0)
# Out:
# plot without title

# %%
plot(x/(pi/3), sin(x), xlim=c(0,max), type='l', col=mypal[1])
# Out:
# plot without title

# %%
1/2 + 1/3+1/4+1/5

# %%
2/3 + 2/4 + 2/5 +

2*gamma
