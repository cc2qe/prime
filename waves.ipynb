# %%
x <- seq(0,100*pi,0.1)

# %%
mypal <- c('steelblue', 'indianred')

# %%
max <- 20

# plot(x/(pi/2), sin(x), xlim=c(0,max), type='l', col=mypal[1])
# points(x/(pi/1), sin(x), xlim=c(0,max), type='l', col=mypal[1])
plot(x/(pi/3), sin(x), xlim=c(0,max), type='l', col=mypal[1])
points(x/(pi/4), sin(x), xlim=c(0,max), type='l', col=mypal[1])
points(x/(pi/5), sin(x), xlim=c(0,max), type='l', col=mypal[1])
points(x/(pi/6), sin(x), xlim=c(0,max), type='l', col=mypal[1])
points(x/(pi/7), sin(x), xlim=c(0,max), type='l', col=mypal[1])

abline(h=0)
for (i in 0:max) {
    abline(v=i)
}
# Out:
# plot without title

# %%
max <- 20

# plot(x/(pi/2), sin(x), xlim=c(0,max), type='l', col=mypal[1])
# points(x/(pi/1), sin(x), xlim=c(0,max), type='l', col=mypal[1])
plot(1, xlim=c(0,max), ylim=c(-1,1), type='n')
for (i in 1:10) {
    points(x/(pi/i), sin(x), xlim=c(0,max), type='l', col=mypal[1])
}

abline(h=0)
# for (i in 0:max) {
#     abline(v=i)
# }
# Out:
# plot without title

# %%
# Out:
# Error in plot.xy(xy.coords(x, y), type = type, ...): plot.new has not been called yet
# Traceback:
#
# 1. points(x/(pi/4), sin(x), xlim = c(0, max), type = "l", col = mypal[1])
# 2. points.default(x/(pi/4), sin(x), xlim = c(0, max), type = "l",
#  .     col = mypal[1])
# 3. plot.xy(xy.coords(x, y), type = type, ...)

# %%
plot(x/(pi/3), sin(x), xlim=c(0,max), type='l', col=mypal[1])
# Out:
# plot without title

# %%
1/2 + 1/3+1/4+1/5

# %%
2/3 + 2/4 + 2/5 +

2*gamma
